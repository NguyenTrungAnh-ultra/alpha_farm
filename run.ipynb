# %%
import sys
sys.path.insert(0, r"d:\IU\Data_Science_talent_Competition_2026")
from agent import run_pipeline, load_cookies

portfolio, stats = run_pipeline(
    cookies=load_cookies(),
    n_strategies=50,
    model="pro",
    n_trials=100,
    request_delay=5.0,
    # Engine overrides (optional — defaults from constants.py)
    # initial_capital=1_000_000_000,
    # margin_rate=0.285,
    # fee_per_contract=6_000,
    # max_correlation=0.5,
)
# Out:
# ╔══════════════════════════════════════════════════════════════╗
# ║           AUTO STRATEGY GENERATION PIPELINE                ║
# ║  Target: 50 strategies | Model: pro                      ║
# ║  Timeframes: 5m, 10m, 15m, 30m, 1m                     ║
# ║  Optimization: 100 trials/strategy (Bayesian)           ║
# ╚══════════════════════════════════════════════════════════════╝
#
# [GeminiChat] Session initialized (nonce=AOOh0PEX4JALoO0ywxX5...)
# [GeminiChat] ✅ Ready | model=pro (gemini-3-pro) | auto-rotate=600s | keepalive=5m
# [Pipeline] GeminiChat ready: GeminiChat(model=pro [gemini-3-pro], requests=0)
# [Portfolio] Loaded 7 strategies, 7 equity curves
# [Pipeline] Portfolio: 7 existing strategies
# [Pipeline] Engine: capital=1,000,000,000 | margin=28.5% | fee=6,000/HĐ/chiều
# [Pipeline] Loading data...
#     5m:   57,147 bars (2020-01-02 → 2024-12-31)
#    10m:   30,250 bars (2020-01-02 → 2024-12-31)
#    15m:   21,285 bars (2020-01-02 → 2024-12-31)
# ...
